# %%
# one_d_maze_abstract_time_to_criterion_control_final
import keras
import hrr as hrr
import numpy as np
from collections import Counter
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
bias = 1.0
reward = 1.0
gamma = 0.9
alpha = 0.01
lambd = 0.0
states = 20
non_reward = 0
hrr_size = 2048
non_goal_states = 0
gates = ['open', 'close']
actions = ['left', 'right']
colors = ['red', 'green', 'purple', 'blue']

runs = 10
ep_down_1 = 3.0
ep_down_2 = 2.0
ep_down_3 = 1.0
fold_counter_ar = []
len_memory_store = []
sub_optimal_goal = 0.5

# %%
def problem(prob):
    rand = np.random.random()
    if sum(prob) > 1:
        print('ERROR CHECK PROBLEM FUNCTION')
    mem = prob[0]
    color = ''
    for i in range(len(prob)):
    #     print(i, "mem =", mem)
        if rand < mem:
            color = colors[i]
            break
        else:
            mem += prob[i+1]
    return color

# %%
# working memory
# this will choose the open/close action

def encode_gate(state, signal, w_m, gate_action):
    string = 'state_'  + str(state) + "*" + \
             'signal_' + str(signal) + "*" + \
             'w_m_' + str(w_m) + "*" + \
             'gate_action' + str(gate_action)
    encoded = np.array([memory.encode(string)])
    return(encoded)

def q_gate(state, signal, w_m):
    max_value = 0
    
    if signal != '':
        signal = 'on'        
    if w_m != '':
        w_m = 'on'
        
    for gate_action in gates:
        hrr = encode_gate(state, signal, w_m, gate_action)
        value = model_gate.predict(hrr)[0,0] + bias
        if value > max_value:
            max_value = value
            max_hrr = hrr
            max_gate = gate_action
    return  max_value, max_hrr, max_gate

# %%
# working memory
# move l/r

def encode_move(state, signal, w_m, phyical_action):
    string = 'state_'  + str(state) + "*" + \
             'signal_' + str(signal) + "*" + \
             'w_m_' + str(w_m) + "*" + \
             'phyical_action' + str(phyical_action)
    encoded = np.array([memory.encode(string)])
    return(encoded)

def q_move(state, signal, w_m):
    max_value = 0
    for phyical_action in actions:
        hrr = encode_move(state, signal, w_m, phyical_action)
        value = model_move.predict(hrr)[0,0] + bias
        if value > max_value:
            max_value = value
            max_hrr = hrr
            max_action = phyical_action
    return  max_value, max_hrr, max_action

# %%
# random mover

def random_q_gate(state, signal, w_m):
    if signal != '':
        signal = 'on'        
    if w_m != '':
        w_m = 'on'

    gate = np.random.choice(gates)
    hrr = encode_gate(state, signal, w_m, gate)
    value = model_gate.predict(hrr)[0,0] + bias
    return value, hrr, gate

def random_q_move(state, signal, w_m):
    phyical_move = np.random.choice(actions)
    hrr = encode_move(state, signal, w_m, phyical_move)
    value = model_move.predict(hrr)[0,0] + bias
    return value, hrr, phyical_move

# %%
for run in range(runs):

    episode = 0
    epsilon = 0.05
    fold_counter = 0
    # if time_to_cry = True   code will skip pre-training
    # if time_to_cry = False  code will      pre-train
#     time_to_cry = True
    time_to_cry = False
    
    ep_one = True
    ep_two = True
    ep_tre = True
    ep_back_on = False
    run_episode = True    
    sub_optimal_steps = []
    sub_optimal_average = []
    fold_sub_optimal_steps = []
    fold_sub_optimal_average = []
    
    memory = hrr.LTM(hrr_size, True)

    model_gate = keras.models.Sequential()
    model_gate.add(keras.layers.Dense(1,input_shape=[hrr_size],use_bias=False))
    model_gate.compile(loss=keras.losses.mse,
                       optimizer=keras.optimizers.SGD(learning_rate=alpha),
                       metrics=['accuracy'])
    model_gate.summary()

    model_move = keras.models.Sequential()
    model_move.add(keras.layers.Dense(1,input_shape=[hrr_size],use_bias=False))
    model_move.compile(loss=keras.losses.mse,
                       optimizer=keras.optimizers.SGD(learning_rate=alpha),
                       metrics=['accuracy'])
    model_move.summary()

    colorar = []

    while run_episode == True:
        
        fold = False

        if (episode+1) % 1000 == 0:
            print("on ", episode+1)
            print('reached ', sub_optimal_average[-1])

        if len(sub_optimal_average) > 0:
            if ep_tre == True:
                if ep_one == True:
                    if sub_optimal_average[-1] < ep_down_1: 
                        epsilon = epsilon/2
                        ep_one = False
                        print('one epsilon changed to:', epsilon)
                        print('reached ', sub_optimal_average[-1])

                elif ep_two == True:
                    if sub_optimal_average[-1] < ep_down_2: 
                        epsilon = epsilon/2
                        ep_two = False
                        print('two epsilon changed to:', epsilon)
                        print('reached ', sub_optimal_average[-1])
                else:
                    if sub_optimal_average[-1] < ep_down_3:
                        epsilon = epsilon/2
                        ep_tre = False
                        print('tre epsilon changed to:', epsilon)
                        print('reached ', sub_optimal_average[-1])

        current_state = np.random.choice(states)
        
        if time_to_cry == False:
            if len(sub_optimal_average) > 0:
                if sub_optimal_average[-1] < sub_optimal_goal:
                    time_to_cry = True
                    print('reached ', sub_optimal_average[-1], 'switch to crying')
                    print('location', len(sub_optimal_average))
                    ep_back_on = True
                    
        if ep_back_on == True:
            if sub_optimal_average[-1] > 4.0:
                epsilon = 0.05
                print('epsilon back on to ', epsilon)
                ep_one = True
                ep_two = True
                ep_tre = True
                ep_back_on = False
            
        if time_to_cry == False:
            prob = [1/2, 1/2, 0, 0]
        else:
            prob = [0, 0, 1/2, 1/2]
            
        current_signal = problem(prob)
        colorar.append(current_signal)
        
        if current_signal == 'purple':
            fold = True
        if current_signal == 'blue':
            fold = True

        if current_signal == 'red':
            goal_state = 2
        elif current_signal == 'green':
            goal_state = 7
        elif current_signal == 'purple':
            goal_state = 12
        else:
            goal_state = 17

        if goal_state < current_state:
            optimal_steps_1 = abs(goal_state - current_state)
            optimal_steps_2 = states - current_state + goal_state
        else:
            optimal_steps_1 = abs(goal_state - current_state)
            optimal_steps_2 = states - goal_state + current_state

        if optimal_steps_1 < optimal_steps_2:
            optimal_steps = optimal_steps_1
        else:
            optimal_steps = optimal_steps_2

        current_w_m = ''

        for step in range(states):

            if current_state == goal_state:
                break

            if np.random.random() < epsilon:
                gate_value, \
                gate_hrr, \
                gate_action = random_q_gate(current_state, current_signal, current_w_m)
                current_value, \
                current_hrr, \
                current_action = random_q_move(current_state, current_signal, current_w_m)         
            else:
                gate_value, \
                gate_hrr, \
                gate_action = q_gate(current_state, current_signal, current_w_m)
                current_value, \
                current_hrr, \
                current_action = q_move(current_state, current_signal, current_w_m)

            previous_state = current_state

            previous_gate_value = gate_value
            previous_gate_hrr = gate_hrr
            previous_gate_action = gate_action

            previous_value = current_value
            previous_hrr = current_hrr
            previous_action = current_action

            if gate_action == 'open':
                current_w_m = current_signal

            current_signal = ''

            if (current_action == "left"):
                current_state = (current_state-1)%states
            else:
                current_state = (current_state+1)%states

            if current_state == goal_state:
                target = reward
            else:
                current_value, _, _ = q_move(current_state, current_signal, current_w_m)
                target = non_goal_states + gamma * current_value

            model_gate.fit(previous_gate_hrr, [target-bias], verbose=0)
            model_move.fit(previous_hrr, [target-bias], verbose=0)

        sub_optimal_steps.append(abs(step-optimal_steps))
        
        if fold == True:
            if (episode+1) % 1000 == 0:
                if len(fold_sub_optimal_average) > 0:
                    print('fold reached ', fold_sub_optimal_average[-1])
            fold_counter += 1
            fold_sub_optimal_steps.append(abs(step-optimal_steps))
            
#             if len(fold_sub_optimal_steps) < 100:
#                 fold_sub_optimal_average.append(sum(fold_sub_optimal_steps)/len(fold_sub_optimal_steps))
#             else:
#                 fold_sub_optimal_average.append(sum(fold_sub_optimal_steps[-100:])/100)

            if len(fold_sub_optimal_steps) > 99:
                fold_sub_optimal_average.append(sum(fold_sub_optimal_steps[-100:])/100)
            
                if fold_sub_optimal_average[-1] < sub_optimal_goal:
                    fold_counter_ar.append(fold_counter)
                    print('number of purple and blue episodes: ', fold_counter)
                    break
                
#         if len(sub_optimal_steps) < 100:
#             sub_optimal_average.append(sum(sub_optimal_steps)/len(sub_optimal_steps))
#         else:
#             sub_optimal_average.append(sum(sub_optimal_steps[-100:])/100)

        if len(sub_optimal_steps) > 99:
            sub_optimal_average.append(sum(sub_optimal_steps[-100:])/100)

        episode += 1

    list_freq = (Counter(colorar))
    
    for key, value in list_freq.items():
        print(key, " has count ", value)
    
    len_memory_store.append(len(memory.store))
    print('size of dictionary ', len(memory.store))
    
    print('last 100 runs average: ', fold_sub_optimal_average[-1])
    
    plt.plot(sub_optimal_average)
    plt.grid(True)
    plt.show()
    
    plt.plot(fold_sub_optimal_average)
    plt.grid(True)
    plt.show()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1)                 2048
# =================================================================
# Total params: 2,048
# Trainable params: 2,048
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 1)                 2048
# =================================================================
# Total params: 2,048
# Trainable params: 2,048
# Non-trainable params: 0
# _________________________________________________________________
# on  1000
# reached  8.25
# on  2000
# reached  5.45
# on  3000
# reached  4.03
# one epsilon changed to: 0.025
# reached  2.97
# on  4000
# reached  2.83
# two epsilon changed to: 0.0125
# reached  1.98
# on  5000
# reached  2.09
# tre epsilon changed to: 0.00625
# reached  0.93
# on  6000
# reached  1.13
# reached  0.48 switch to crying
# location 6493
# epsilon back on to  0.05
# on  7000
# reached  8.05
# fold reached  8.05
# on  8000
# reached  5.68
# fold reached  5.68
# on  9000
# reached  3.95
# fold reached  3.95
# one epsilon changed to: 0.025
# reached  2.9
# two epsilon changed to: 0.0125
# reached  1.94
# on  10000
# reached  2.18
# fold reached  2.18
# tre epsilon changed to: 0.00625
# reached  0.94
# on  11000
# reached  1.33
# fold reached  1.33
# on  12000
# reached  0.5
# fold reached  0.5
# number of purple and blue episodes:  5411
# red  has count  3276
# green  has count  3316
# purple  has count  2748
# blue  has count  2663
# size of dictionary  1632
# last 100 runs average:  0.48
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 1)                 2048
# =================================================================
# Total params: 2,048
# Trainable params: 2,048
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 1)                 2048
# =================================================================
# Total params: 2,048
# Trainable params: 2,048
# Non-trainable params: 0
# _________________________________________________________________
# on  1000
# reached  7.36
# on  2000
# reached  6.11
# on  3000
# reached  4.86
# one epsilon changed to: 0.025
# reached  2.99
# on  4000
# reached  3.6
# two epsilon changed to: 0.0125
# reached  1.98
# on  5000
# reached  2.14
# on  6000
# reached  1.45
# tre epsilon changed to: 0.00625
# reached  0.91
# reached  0.49 switch to crying
# location 6869
# on  7000
# reached  3.74
# epsilon back on to  0.05
# on  8000
# reached  5.07
# fold reached  5.07
# on  9000
# reached  3.69
# fold reached  3.69
# one epsilon changed to: 0.025
# reached  2.99
# on  10000
# reached  2.81
# fold reached  2.81
# two epsilon changed to: 0.0125
# reached  1.95
# tre epsilon changed to: 0.00625
# reached  0.99
# on  11000
# reached  1.88
# fold reached  1.88
# on  12000
# reached  1.25
# fold reached  1.25
# number of purple and blue episodes:  5988
# green  has count  3520
# red  has count  3448
# purple  has count  2987
# blue  has count  3001
# size of dictionary  1632
# last 100 runs average:  0.46
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 1)                 2048
# =================================================================
# Total params: 2,048
# Trainable params: 2,048
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 1)                 2048
# =================================================================
# Total params: 2,048
# Trainable params: 2,048
# Non-trainable params: 0
# _________________________________________________________________
# on  1000
# reached  7.51
# on  2000
# reached  6.4
# on  3000
# reached  4.46
# one epsilon changed to: 0.025
# reached  2.92
# on  4000
# reached  2.78
# two epsilon changed to: 0.0125
# reached  1.99
# on  5000
# reached  2.47
# tre epsilon changed to: 0.00625
# reached  0.99
# on  6000
# reached  1.22
# on  7000
# reached  1.02
# reached  0.42 switch to crying
# location 7428
# epsilon back on to  0.05
# on  8000
# reached  8.98
# fold reached  8.98
# on  9000
# reached  5.12
# fold reached  5.12
# one epsilon changed to: 0.025
# reached  2.96
# on  10000
# reached  2.34
# fold reached  2.34
# two epsilon changed to: 0.0125
# reached  1.93
# on  11000
# reached  1.15
# fold reached  1.15
# tre epsilon changed to: 0.00625
# reached  0.96
# number of purple and blue episodes:  4153
# red  has count  3865
# green  has count  3662
# purple  has count  2051
# blue  has count  2102
# size of dictionary  1632
# last 100 runs average:  0.46
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 1)                 2048
# =================================================================
# Total params: 2,048
# Trainable params: 2,048
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_8 (Dense)              (None, 1)                 2048
# =================================================================
# Total params: 2,048
# Trainable params: 2,048
# Non-trainable params: 0
# _________________________________________________________________
# on  1000
# reached  8.06
# on  2000
# reached  5.85
# on  3000
# reached  5.06
# on  4000
# reached  3.75
# one epsilon changed to: 0.025
# reached  2.93
# on  5000
# reached  2.93
# two epsilon changed to: 0.0125
# reached  1.97
# tre epsilon changed to: 0.00625
# reached  0.98
# on  6000
# reached  1.38
# reached  0.48 switch to crying
# location 6631
# epsilon back on to  0.05
# on  7000
# reached  9.66
# fold reached  9.66
# on  8000
# reached  4.7
# fold reached  4.7
# one epsilon changed to: 0.025
# reached  2.99
# on  9000
# reached  2.8
# fold reached  2.8
# two epsilon changed to: 0.0125
# reached  1.98
# on  10000
# reached  1.35
# fold reached  1.35
# tre epsilon changed to: 0.00625
# reached  0.94
# on  11000
# reached  1.47
# fold reached  1.47
# on  12000
# reached  0.65
# fold reached  0.65
# number of purple and blue episodes:  5484
# red  has count  3315
# green  has count  3415
# blue  has count  2736
# purple  has count  2748
# size of dictionary  1632
# last 100 runs average:  0.49
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_9 (Dense)              (None, 1)                 2048
# =================================================================
# Total params: 2,048
# Trainable params: 2,048
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 1)                 2048
# =================================================================
# Total params: 2,048
# Trainable params: 2,048
# Non-trainable params: 0
# _________________________________________________________________
# on  1000
# reached  7.16
# on  2000
# reached  7.08
# on  3000
# reached  4.11
# on  4000
# reached  3.41
# one epsilon changed to: 0.025
# reached  2.95
# two epsilon changed to: 0.0125
# reached  1.93
# on  5000
# reached  2.29
# tre epsilon changed to: 0.00625
# reached  0.93
# on  6000
# reached  1.92
# reached  0.46 switch to crying
# location 6462
# epsilon back on to  0.05
# on  7000
# reached  9.11
# fold reached  9.11
# on  8000
# reached  3.77
# fold reached  3.77
# on  9000
# reached  4.01
# fold reached  4.01
# one epsilon changed to: 0.025
# reached  2.93
# two epsilon changed to: 0.0125
# reached  1.99
# on  10000
# reached  1.85
# fold reached  1.85
# tre epsilon changed to: 0.00625
# reached  0.97
# on  11000
# reached  1.53
# fold reached  1.53
# on  12000
# reached  0.81
# fold reached  0.81
# number of purple and blue episodes:  5999
# red  has count  3342
# green  has count  3219
# blue  has count  3010
# purple  has count  2989
# size of dictionary  1632
# last 100 runs average:  0.46
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_11 (Dense)             (None, 1)                 2048
# =================================================================
# Total params: 2,048
# Trainable params: 2,048
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 1)                 2048
# =================================================================
# Total params: 2,048
# Trainable params: 2,048
# Non-trainable params: 0
# _________________________________________________________________
# on  1000
# reached  7.97
# on  2000
# reached  6.86
# on  3000
# reached  5.31
# on  4000
# reached  3.02
# one epsilon changed to: 0.025
# reached  2.9
# two epsilon changed to: 0.0125
# reached  1.99
# on  5000
# reached  1.88
# tre epsilon changed to: 0.00625
# reached  0.95
# on  6000
# reached  1.02
# on  7000
# reached  1.12
# reached  0.46 switch to crying
# location 7092
# epsilon back on to  0.05
# on  8000
# reached  5.62
# fold reached  5.62
# on  9000
# reached  4.03
# fold reached  4.03
# one epsilon changed to: 0.025
# reached  2.99
# two epsilon changed to: 0.0125
# reached  1.99
# on  10000
# reached  3.05
# fold reached  3.05
# on  11000
# reached  1.28
# fold reached  1.28
# tre epsilon changed to: 0.00625
# reached  0.97
# on  12000
# reached  0.98
# fold reached  0.98
# number of purple and blue episodes:  5268
# red  has count  3625
# green  has count  3566
# purple  has count  2599
# blue  has count  2669
# size of dictionary  1632
# last 100 runs average:  0.46
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_13 (Dense)             (None, 1)                 2048
# =================================================================
# Total params: 2,048
# Trainable params: 2,048
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_14 (Dense)             (None, 1)                 2048
# =================================================================
# Total params: 2,048
# Trainable params: 2,048
# Non-trainable params: 0
# _________________________________________________________________
# on  1000
# reached  7.55
# on  2000
# reached  6.78
# on  3000
# reached  4.96
# one epsilon changed to: 0.025
# reached  2.95
# on  4000
# reached  2.7
# two epsilon changed to: 0.0125
# reached  1.91
# on  5000
# reached  2.15
# on  6000
# reached  1.66
# tre epsilon changed to: 0.00625
# reached  0.94
# reached  0.49 switch to crying
# location 6427
# epsilon back on to  0.05
# on  7000
# reached  9.98
# fold reached  9.98
# on  8000
# reached  4.36
# fold reached  4.36
# one epsilon changed to: 0.025
# reached  2.99
# two epsilon changed to: 0.0125
# reached  1.92
# on  9000
# reached  2.84
# fold reached  2.84
# on  10000
# reached  1.56
# fold reached  1.56
# tre epsilon changed to: 0.00625
# reached  0.98
# on  11000
# reached  1.35
# fold reached  1.35
# number of purple and blue episodes:  5315
# green  has count  3282
# red  has count  3244
# purple  has count  2629
# blue  has count  2686
# size of dictionary  1632
# last 100 runs average:  0.46
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_15 (Dense)             (None, 1)                 2048
# =================================================================
# Total params: 2,048
# Trainable params: 2,048
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_16 (Dense)             (None, 1)                 2048
# =================================================================
# Total params: 2,048
# Trainable params: 2,048
# Non-trainable params: 0
# _________________________________________________________________
# on  1000
# reached  8.22
# on  2000
# reached  7.72
# on  3000
# reached  4.72
# one epsilon changed to: 0.025
# reached  2.91
# on  4000
# reached  3.5
# two epsilon changed to: 0.0125
# reached  1.95
# on  5000
# reached  1.5
# tre epsilon changed to: 0.00625
# reached  0.98
# reached  0.48 switch to crying
# location 5680
# epsilon back on to  0.05
# on  6000
# reached  9.54
# fold reached  9.54
# on  7000
# reached  4.7
# fold reached  4.7
# one epsilon changed to: 0.025
# reached  2.99
# on  8000
# reached  2.83
# fold reached  2.83
# two epsilon changed to: 0.0125
# reached  1.94
# on  9000
# reached  1.61
# fold reached  1.61
# tre epsilon changed to: 0.00625
# reached  0.89
# on  10000
# reached  1.38
# fold reached  1.38
# number of purple and blue episodes:  4850
# green  has count  2941
# red  has count  2838
# purple  has count  2379
# blue  has count  2471
# size of dictionary  1632
# last 100 runs average:  0.48
# Model: "sequential_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_17 (Dense)             (None, 1)                 2048
# =================================================================
# Total params: 2,048
# Trainable params: 2,048
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_18 (Dense)             (None, 1)                 2048
# =================================================================
# Total params: 2,048
# Trainable params: 2,048
# Non-trainable params: 0
# _________________________________________________________________
# on  1000
# reached  8.64
# on  2000
# reached  7.52
# on  3000
# reached  5.52
# one epsilon changed to: 0.025
# reached  2.91
# on  4000
# reached  3.09
# two epsilon changed to: 0.0125
# reached  1.98
# on  5000
# reached  2.77
# on  6000
# reached  1.36
# tre epsilon changed to: 0.00625
# reached  0.96
# reached  0.42 switch to crying
# location 6765
# epsilon back on to  0.05
# on  7000
# reached  11.9
# fold reached  11.9
# on  8000
# reached  5.09
# fold reached  5.09
# one epsilon changed to: 0.025
# reached  2.97
# on  9000
# reached  3.5
# fold reached  3.5
# two epsilon changed to: 0.0125
# reached  1.98
# on  10000
# reached  1.62
# fold reached  1.62
# tre epsilon changed to: 0.00625
# reached  0.98
# on  11000
# reached  0.62
# fold reached  0.62
# on  12000
# reached  0.87
# fold reached  0.87
# number of purple and blue episodes:  5322
# red  has count  3388
# green  has count  3476
# purple  has count  2673
# blue  has count  2649
# size of dictionary  1632
# last 100 runs average:  0.48
# Model: "sequential_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_19 (Dense)             (None, 1)                 2048
# =================================================================
# Total params: 2,048
# Trainable params: 2,048
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_20"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_20 (Dense)             (None, 1)                 2048
# =================================================================
# Total params: 2,048
# Trainable params: 2,048
# Non-trainable params: 0
# _________________________________________________________________
# on  1000
# reached  8.14
# on  2000
# reached  6.68
# on  3000
# reached  5.34
# one epsilon changed to: 0.025
# reached  2.97
# on  4000
# reached  3.07
# two epsilon changed to: 0.0125
# reached  1.96
# on  5000
# reached  1.62
# tre epsilon changed to: 0.00625
# reached  0.93
# on  6000
# reached  2.04
# reached  0.49 switch to crying
# location 6871
# on  7000
# reached  3.51
# epsilon back on to  0.05
# on  8000
# reached  4.64
# fold reached  4.64
# one epsilon changed to: 0.025
# reached  2.95
# on  9000
# reached  3.15
# fold reached  3.15
# two epsilon changed to: 0.0125
# reached  1.97
# on  10000
# reached  2.53
# fold reached  2.53
# tre epsilon changed to: 0.00625
# reached  0.97
# on  11000
# reached  0.74
# fold reached  0.74
# number of purple and blue episodes:  4816
# red  has count  3519
# green  has count  3451
# blue  has count  2406
# purple  has count  2410
# size of dictionary  1632
# last 100 runs average:  0.48

# %%
len_memory_store
# Out:
# [1632, 1632, 1632, 1632, 1632, 1632, 1632, 1632, 1632, 1632]

# %%
fold_counter_ar
# Out:
# [5411, 5988, 4153, 5484, 5999, 5268, 5315, 4850, 5322, 4816]

# %%
stan_error = np.std(fold_counter_ar)/np.sqrt(len(fold_counter_ar))

# %%
mean = np.mean(fold_counter_ar)
mean
# Out:
# 5260.6

# %%
upper_limit = mean + (1.96 * stan_error)
upper_limit
# Out:
# 5585.4339405025285

# %%
lower_limit = mean - (1.96 * stan_error)
lower_limit
# Out:
# 4935.766059497472

# %%
1.96 * stan_error
# Out:
# 324.83394050252815
