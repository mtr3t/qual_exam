# %%
# one_d_maze_abstract_time_to_criterion_control_final
import keras
import hrr as hrr
import numpy as np
from collections import Counter
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
bias = 1.0
reward = 1.0
gamma = 0.9
alpha = 0.01
lambd = 0.0
states = 20
non_reward = 0
hrr_size = 2048
non_goal_states = 0
gates = ['open', 'close']
actions = ['left', 'right']
colors = ['red', 'green', 'purple', 'blue']

runs = 10
ep_down_1 = 3.0
ep_down_2 = 2.0
ep_down_3 = 1.0
fold_counter_ar = []
len_memory_store = []
sub_optimal_goal = 0.5

# %%
def problem(prob):
    rand = np.random.random()
    if sum(prob) > 1:
        print('ERROR CHECK PROBLEM FUNCTION')
    mem = prob[0]
    color = ''
    for i in range(len(prob)):
    #     print(i, "mem =", mem)
        if rand < mem:
            color = colors[i]
            break
        else:
            mem += prob[i+1]
    return color

# %%
# working memory
# this will choose the open/close action

def encode_gate(state, signal, w_m, gate_action):
    string = 'state_'  + str(state) + "*" + \
             'signal_' + str(signal) + "*" + \
             'w_m_' + str(w_m) + "*" + \
             'gate_action' + str(gate_action)
    encoded = np.array([memory.encode(string)])
    return(encoded)

def q_gate(state, signal, w_m):
    max_value = 0
    
    if signal != '':
        signal = 'on'        
    if w_m != '':
        w_m = 'on'
        
    for gate_action in gates:
        hrr = encode_gate(state, signal, w_m, gate_action)
        value = model_gate.predict(hrr)[0,0] + bias
        if value > max_value:
            max_value = value
            max_hrr = hrr
            max_gate = gate_action
    return  max_value, max_hrr, max_gate

# %%
# working memory
# move l/r

def encode_move(state, signal, w_m, phyical_action):
    string = 'state_'  + str(state) + "*" + \
             'signal_' + str(signal) + "*" + \
             'w_m_' + str(w_m) + "*" + \
             'phyical_action' + str(phyical_action)
    encoded = np.array([memory.encode(string)])
    return(encoded)

def q_move(state, signal, w_m):
    max_value = 0
    for phyical_action in actions:
        hrr = encode_move(state, signal, w_m, phyical_action)
        value = model_move.predict(hrr)[0,0] + bias
        if value > max_value:
            max_value = value
            max_hrr = hrr
            max_action = phyical_action
    return  max_value, max_hrr, max_action

# %%
# random mover

def random_q_gate(state, signal, w_m):
    if signal != '':
        signal = 'on'        
    if w_m != '':
        w_m = 'on'

    gate = np.random.choice(gates)
    hrr = encode_gate(state, signal, w_m, gate)
    value = model_gate.predict(hrr)[0,0] + bias
    return value, hrr, gate

def random_q_move(state, signal, w_m):
    phyical_move = np.random.choice(actions)
    hrr = encode_move(state, signal, w_m, phyical_move)
    value = model_move.predict(hrr)[0,0] + bias
    return value, hrr, phyical_move

# %%
for run in range(runs):

    episode = 0
    epsilon = 0.05
    fold_counter = 0
    # if time_to_cry = True   code will skip pre-training
    # if time_to_cry = False  code will      pre-train
#     time_to_cry = True
    time_to_cry = False
    
    ep_one = True
    ep_two = True
    ep_tre = True
    ep_back_on = False
    run_episode = True    
    sub_optimal_steps = []
    sub_optimal_average = []
    fold_sub_optimal_steps = []
    fold_sub_optimal_average = []
    
    memory = hrr.LTM(hrr_size, True)

    model_gate = keras.models.Sequential()
    model_gate.add(keras.layers.Dense(1,input_shape=[hrr_size],use_bias=False))
    model_gate.compile(loss=keras.losses.mse,
                       optimizer=keras.optimizers.SGD(learning_rate=alpha),
                       metrics=['accuracy'])
    model_gate.summary()

    model_move = keras.models.Sequential()
    model_move.add(keras.layers.Dense(1,input_shape=[hrr_size],use_bias=False))
    model_move.compile(loss=keras.losses.mse,
                       optimizer=keras.optimizers.SGD(learning_rate=alpha),
                       metrics=['accuracy'])
    model_move.summary()

    colorar = []

    while run_episode == True:
        
        fold = False

        if (episode+1) % 1000 == 0:
            print("on ", episode+1)
            print('reached ', sub_optimal_average[-1])

        if len(sub_optimal_average) > 0:
            if ep_tre == True:
                if ep_one == True:
                    if sub_optimal_average[-1] < ep_down_1: 
                        epsilon = epsilon/2
                        ep_one = False
                        print('one epsilon changed to:', epsilon)
                        print('reached ', sub_optimal_average[-1])

                elif ep_two == True:
                    if sub_optimal_average[-1] < ep_down_2: 
                        epsilon = epsilon/2
                        ep_two = False
                        print('two epsilon changed to:', epsilon)
                        print('reached ', sub_optimal_average[-1])
                else:
                    if sub_optimal_average[-1] < ep_down_3:
                        epsilon = epsilon/2
                        ep_tre = False
                        print('tre epsilon changed to:', epsilon)
                        print('reached ', sub_optimal_average[-1])

        current_state = np.random.choice(states)
        
        if time_to_cry == False:
            if len(sub_optimal_average) > 0:
                if sub_optimal_average[-1] < sub_optimal_goal:
                    time_to_cry = True
                    print('reached ', sub_optimal_average[-1], 'switch to crying')
                    print('location', len(sub_optimal_average))
                    ep_back_on = True
                    
        if ep_back_on == True:
            if sub_optimal_average[-1] > 4.0:
                epsilon = 0.05
                print('epsilon back on to ', epsilon)
                ep_one = True
                ep_two = True
                ep_tre = True
                ep_back_on = False
            
        if time_to_cry == False:
            prob = [1/2, 1/2, 0, 0]
        else:
            prob = [1/4, 1/4, 1/4, 1/4]
            
        current_signal = problem(prob)
        colorar.append(current_signal)
        
        if current_signal == 'purple':
            fold = True
        if current_signal == 'blue':
            fold = True

        if current_signal == 'red':
            goal_state = 2
        elif current_signal == 'green':
            goal_state = 7
        elif current_signal == 'purple':
            goal_state = 12
        else:
            goal_state = 17

        if goal_state < current_state:
            optimal_steps_1 = abs(goal_state - current_state)
            optimal_steps_2 = states - current_state + goal_state
        else:
            optimal_steps_1 = abs(goal_state - current_state)
            optimal_steps_2 = states - goal_state + current_state

        if optimal_steps_1 < optimal_steps_2:
            optimal_steps = optimal_steps_1
        else:
            optimal_steps = optimal_steps_2

        current_w_m = ''

        for step in range(states):

            if current_state == goal_state:
                break

            if np.random.random() < epsilon:
                gate_value, \
                gate_hrr, \
                gate_action = random_q_gate(current_state, current_signal, current_w_m)
                current_value, \
                current_hrr, \
                current_action = random_q_move(current_state, current_signal, current_w_m)         
            else:
                gate_value, \
                gate_hrr, \
                gate_action = q_gate(current_state, current_signal, current_w_m)
                current_value, \
                current_hrr, \
                current_action = q_move(current_state, current_signal, current_w_m)

            previous_state = current_state

            previous_gate_value = gate_value
            previous_gate_hrr = gate_hrr
            previous_gate_action = gate_action

            previous_value = current_value
            previous_hrr = current_hrr
            previous_action = current_action

            if gate_action == 'open':
                current_w_m = current_signal

            current_signal = ''

            if (current_action == "left"):
                current_state = (current_state-1)%states
            else:
                current_state = (current_state+1)%states

            if current_state == goal_state:
                target = reward
            else:
                current_value, _, _ = q_move(current_state, current_signal, current_w_m)
                target = non_goal_states + gamma * current_value

            model_gate.fit(previous_gate_hrr, [target-bias], verbose=0)
            model_move.fit(previous_hrr, [target-bias], verbose=0)

        sub_optimal_steps.append(abs(step-optimal_steps))
        
        if fold == True:
            if (episode+1) % 1000 == 0:
                if len(fold_sub_optimal_average) > 0:
                    print('fold reached ', fold_sub_optimal_average[-1])
            fold_counter += 1
            fold_sub_optimal_steps.append(abs(step-optimal_steps))
            
#             if len(fold_sub_optimal_steps) < 100:
#                 fold_sub_optimal_average.append(sum(fold_sub_optimal_steps)/len(fold_sub_optimal_steps))
#             else:
#                 fold_sub_optimal_average.append(sum(fold_sub_optimal_steps[-100:])/100)

            if len(fold_sub_optimal_steps) > 99:
                fold_sub_optimal_average.append(sum(fold_sub_optimal_steps[-100:])/100)
            
                if fold_sub_optimal_average[-1] < sub_optimal_goal:
                    fold_counter_ar.append(fold_counter)
                    print('number of purple and blue episodes: ', fold_counter)
                    break
                
#         if len(sub_optimal_steps) < 100:
#             sub_optimal_average.append(sum(sub_optimal_steps)/len(sub_optimal_steps))
#         else:
#             sub_optimal_average.append(sum(sub_optimal_steps[-100:])/100)

        if len(sub_optimal_steps) > 99:
            sub_optimal_average.append(sum(sub_optimal_steps[-100:])/100)

        episode += 1

    list_freq = (Counter(colorar))
    
    for key, value in list_freq.items():
        print(key, " has count ", value)
    
    len_memory_store.append(len(memory.store))
    print('size of dictionary ', len(memory.store))
    
    print('last 100 runs average: ', fold_sub_optimal_average[-1])
    
    plt.plot(sub_optimal_average)
    plt.grid(True)
    plt.show()
    
    plt.plot(fold_sub_optimal_average)
    plt.grid(True)
    plt.show()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1)                 2048
# =================================================================
# Total params: 2,048
# Trainable params: 2,048
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 1)                 2048
# =================================================================
# Total params: 2,048
# Trainable params: 2,048
# Non-trainable params: 0
# _________________________________________________________________
# on  1000
# reached  7.26
# on  2000
# reached  5.8
# on  3000
# reached  4.75
# one epsilon changed to: 0.025
# reached  2.98
# on  4000
# reached  2.94
# on  5000
# reached  2.85
# two epsilon changed to: 0.0125
# reached  1.96
# on  6000
# reached  2.29
# tre epsilon changed to: 0.00625
# reached  0.92
# on  7000
# reached  0.93
# on  8000
# reached  0.99
# reached  0.46 switch to crying
# location 8676
# epsilon back on to  0.05
# on  9000
# reached  6.09
# fold reached  12.22
# on  10000
# reached  5.85
# on  11000
# reached  3.93
# fold reached  6.08
# one epsilon changed to: 0.025
# reached  2.99
# on  12000
# reached  3.01
# fold reached  4.12
# two epsilon changed to: 0.0125
# reached  1.97
# on  13000
# reached  2.17
# fold reached  2.96
# on  14000
# reached  1.65
# fold reached  2.5
# tre epsilon changed to: 0.00625
# reached  0.97
# on  15000
# reached  1.45
# on  16000
# reached  0.7
# fold reached  0.97
# on  17000
# reached  1.03
# on  18000
# reached  0.77
# number of purple and blue episodes:  4658
# green  has count  6721
# red  has count  6898
# purple  has count  2376
# blue  has count  2282
# size of dictionary  1632
# last 100 runs average:  0.48
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 1)                 2048
# =================================================================
# Total params: 2,048
# Trainable params: 2,048
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 1)                 2048
# =================================================================
# Total params: 2,048
# Trainable params: 2,048
# Non-trainable params: 0
# _________________________________________________________________
# on  1000
# reached  8.04
# on  2000
# reached  7.79
# on  3000
# reached  6.2
# on  4000
# reached  4.8
# one epsilon changed to: 0.025
# reached  2.86
# on  5000
# reached  3.21
# two epsilon changed to: 0.0125
# reached  1.9
# on  6000
# reached  2.53
# on  7000
# reached  1.73
# tre epsilon changed to: 0.00625
# reached  0.95
# on  8000
# reached  1.02
# reached  0.47 switch to crying
# location 8490
# epsilon back on to  0.05
# on  9000
# reached  5.45
# on  10000
# reached  5.07
# fold reached  8.94
# on  11000
# reached  3.92
# fold reached  4.87
# one epsilon changed to: 0.025
# reached  2.91
# two epsilon changed to: 0.0125
# reached  1.96
# on  12000
# reached  2.43
# on  13000
# reached  1.39
# fold reached  1.75
# tre epsilon changed to: 0.00625
# reached  0.98
# on  14000
# reached  1.16
# on  15000
# reached  0.76
# fold reached  0.89
# on  16000
# reached  0.6
# fold reached  0.8
# on  17000
# reached  0.91
# fold reached  0.6
# on  18000
# reached  0.72
# number of purple and blue episodes:  4817
# green  has count  6627
# red  has count  6596
# purple  has count  2440
# blue  has count  2377
# size of dictionary  1632
# last 100 runs average:  0.46
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 1)                 2048
# =================================================================
# Total params: 2,048
# Trainable params: 2,048
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 1)                 2048
# =================================================================
# Total params: 2,048
# Trainable params: 2,048
# Non-trainable params: 0
# _________________________________________________________________
# on  1000
# reached  8.42
# on  2000
# reached  6.11
# on  3000
# reached  5.9
# on  4000
# reached  4.01
# one epsilon changed to: 0.025
# reached  2.99
# on  5000
# reached  2.46
# two epsilon changed to: 0.0125
# reached  1.94
# on  6000
# reached  1.88
# tre epsilon changed to: 0.00625
# reached  0.91
# reached  0.49 switch to crying
# location 6778
# epsilon back on to  0.05
# on  7000
# reached  5.47
# on  8000
# reached  4.96
# fold reached  7.22
# one epsilon changed to: 0.025
# reached  2.94
# on  9000
# reached  3.31
# on  10000
# reached  2.09
# two epsilon changed to: 0.0125
# reached  1.93
# tre epsilon changed to: 0.00625
# reached  0.97
# on  11000
# reached  1.44
# fold reached  2.7
# on  12000
# reached  0.98
# on  13000
# reached  0.76
# fold reached  1.33
# on  14000
# reached  0.54
# on  15000
# reached  0.46
# on  16000
# reached  0.52
# number of purple and blue episodes:  5041
# green  has count  5986
# red  has count  5899
# blue  has count  2543
# purple  has count  2498
# size of dictionary  1632
# last 100 runs average:  0.48
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 1)                 2048
# =================================================================
# Total params: 2,048
# Trainable params: 2,048
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_8 (Dense)              (None, 1)                 2048
# =================================================================
# Total params: 2,048
# Trainable params: 2,048
# Non-trainable params: 0
# _________________________________________________________________
# on  1000
# reached  7.61
# on  2000
# reached  6.23
# on  3000
# reached  4.84
# one epsilon changed to: 0.025
# reached  2.95
# on  4000
# reached  2.86
# two epsilon changed to: 0.0125
# reached  1.98
# on  5000
# reached  1.83
# tre epsilon changed to: 0.00625
# reached  0.98
# on  6000
# reached  0.72
# reached  0.48 switch to crying
# location 6471
# epsilon back on to  0.05
# on  7000
# reached  6.51
# fold reached  9.83
# on  8000
# reached  3.79
# one epsilon changed to: 0.025
# reached  2.91
# on  9000
# reached  3.15
# two epsilon changed to: 0.0125
# reached  1.98
# on  10000
# reached  1.66
# fold reached  2.57
# on  11000
# reached  1.81
# fold reached  2.12
# tre epsilon changed to: 0.00625
# reached  0.97
# on  12000
# reached  1.08
# on  13000
# reached  0.74
# on  14000
# reached  0.44
# fold reached  1.16
# on  15000
# reached  0.8
# fold reached  1.42
# on  16000
# reached  0.72
# number of purple and blue episodes:  4858
# red  has count  5613
# green  has count  5577
# blue  has count  2408
# purple  has count  2450
# size of dictionary  1632
# last 100 runs average:  0.48
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_9 (Dense)              (None, 1)                 2048
# =================================================================
# Total params: 2,048
# Trainable params: 2,048
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 1)                 2048
# =================================================================
# Total params: 2,048
# Trainable params: 2,048
# Non-trainable params: 0
# _________________________________________________________________
# on  1000
# reached  8.94
# on  2000
# reached  6.13
# on  3000
# reached  5.68
# on  4000
# reached  3.67
# one epsilon changed to: 0.025
# reached  2.98
# two epsilon changed to: 0.0125
# reached  1.93
# on  5000
# reached  2.03
# on  6000
# reached  1.82
# tre epsilon changed to: 0.00625
# reached  0.94
# on  7000
# reached  1.17
# reached  0.46 switch to crying
# location 7351
# epsilon back on to  0.05
# on  8000
# reached  5.24
# fold reached  9.84
# one epsilon changed to: 0.025
# reached  2.93
# on  9000
# reached  3.58
# fold reached  5.09
# on  10000
# reached  2.62
# two epsilon changed to: 0.0125
# reached  1.97
# on  11000
# reached  2.18
# on  12000
# reached  1.66
# tre epsilon changed to: 0.00625
# reached  0.98
# on  13000
# reached  0.64
# on  14000
# reached  0.72
# on  15000
# reached  0.78
# on  16000
# reached  1.25
# fold reached  1.15
# on  17000
# reached  0.28
# fold reached  0.58
# number of purple and blue episodes:  4855
# red  has count  6125
# green  has count  6101
# blue  has count  2493
# purple  has count  2362
# size of dictionary  1632
# last 100 runs average:  0.46
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_11 (Dense)             (None, 1)                 2048
# =================================================================
# Total params: 2,048
# Trainable params: 2,048
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 1)                 2048
# =================================================================
# Total params: 2,048
# Trainable params: 2,048
# Non-trainable params: 0
# _________________________________________________________________
# on  1000
# reached  7.8
# on  2000
# reached  6.92
# on  3000
# reached  5.94
# on  4000
# reached  5.09
# one epsilon changed to: 0.025
# reached  2.99
# on  5000
# reached  2.81
# two epsilon changed to: 0.0125
# reached  1.93
# tre epsilon changed to: 0.00625
# reached  0.92
# on  6000
# reached  0.78
# reached  0.42 switch to crying
# location 6753
# epsilon back on to  0.05
# on  7000
# reached  5.82
# on  8000
# reached  4.55
# on  9000
# reached  4.66
# one epsilon changed to: 0.025
# reached  2.94
# two epsilon changed to: 0.0125
# reached  1.96
# on  10000
# reached  1.51
# on  11000
# reached  2.16
# fold reached  2.79
# tre epsilon changed to: 0.00625
# reached  0.99
# on  12000
# reached  1.77
# fold reached  2.76
# on  13000
# reached  0.86
# fold reached  1.58
# on  14000
# reached  0.89
# on  15000
# reached  0.46
# on  16000
# reached  0.57
# number of purple and blue episodes:  4856
# green  has count  5914
# red  has count  5933
# purple  has count  2425
# blue  has count  2431
# size of dictionary  1632
# last 100 runs average:  0.48
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_13 (Dense)             (None, 1)                 2048
# =================================================================
# Total params: 2,048
# Trainable params: 2,048
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_14 (Dense)             (None, 1)                 2048
# =================================================================
# Total params: 2,048
# Trainable params: 2,048
# Non-trainable params: 0
# _________________________________________________________________
# on  1000
# reached  7.37
# on  2000
# reached  6.81
# on  3000
# reached  4.53
# one epsilon changed to: 0.025
# reached  2.99
# on  4000
# reached  3.39
# two epsilon changed to: 0.0125
# reached  1.96
# on  5000
# reached  2.53
# tre epsilon changed to: 0.00625
# reached  0.99
# on  6000
# reached  1.38
# reached  0.48 switch to crying
# location 6040
# epsilon back on to  0.05
# on  7000
# reached  5.79
# fold reached  10.71
# on  8000
# reached  4.25
# one epsilon changed to: 0.025
# reached  2.99
# on  9000
# reached  2.7
# on  10000
# reached  2.2
# fold reached  3.46
# two epsilon changed to: 0.0125
# reached  1.95
# on  11000
# reached  1.77
# tre epsilon changed to: 0.00625
# reached  0.99
# on  12000
# reached  1.39
# fold reached  2.16
# on  13000
# reached  0.93
# on  14000
# reached  0.48
# on  15000
# reached  0.86
# on  16000
# reached  0.94
# number of purple and blue episodes:  5170
# red  has count  5613
# green  has count  5651
# blue  has count  2610
# purple  has count  2560
# size of dictionary  1632
# last 100 runs average:  0.48
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_15 (Dense)             (None, 1)                 2048
# =================================================================
# Total params: 2,048
# Trainable params: 2,048
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_16 (Dense)             (None, 1)                 2048
# =================================================================
# Total params: 2,048
# Trainable params: 2,048
# Non-trainable params: 0
# _________________________________________________________________
# on  1000
# reached  8.0
# on  2000
# reached  5.88
# on  3000
# reached  5.24
# one epsilon changed to: 0.025
# reached  2.97
# on  4000
# reached  3.7
# two epsilon changed to: 0.0125
# reached  1.98
# on  5000
# reached  2.87
# tre epsilon changed to: 0.00625
# reached  0.96
# on  6000
# reached  0.94
# reached  0.46 switch to crying
# location 6795
# epsilon back on to  0.05
# on  7000
# reached  6.96
# on  8000
# reached  5.03
# one epsilon changed to: 0.025
# reached  2.97
# on  9000
# reached  3.99
# fold reached  4.37
# two epsilon changed to: 0.0125
# reached  1.99
# on  10000
# reached  1.61
# on  11000
# reached  2.3
# on  12000
# reached  1.43
# fold reached  2.13
# tre epsilon changed to: 0.00625
# reached  0.96
# on  13000
# reached  1.49
# on  14000
# reached  0.94
# fold reached  2.14
# on  15000
# reached  0.6
# on  16000
# reached  0.54
# on  17000
# reached  1.13
# fold reached  1.16
# on  18000
# reached  0.54
# number of purple and blue episodes:  5916
# red  has count  6287
# green  has count  6399
# purple  has count  2929
# blue  has count  2987
# size of dictionary  1632
# last 100 runs average:  0.48
# Model: "sequential_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_17 (Dense)             (None, 1)                 2048
# =================================================================
# Total params: 2,048
# Trainable params: 2,048
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_18 (Dense)             (None, 1)                 2048
# =================================================================
# Total params: 2,048
# Trainable params: 2,048
# Non-trainable params: 0
# _________________________________________________________________
# on  1000
# reached  8.38
# on  2000
# reached  6.09
# on  3000
# reached  3.47
# one epsilon changed to: 0.025
# reached  2.98
# on  4000
# reached  3.1
# two epsilon changed to: 0.0125
# reached  1.98
# on  5000
# reached  1.51
# tre epsilon changed to: 0.00625
# reached  0.96
# on  6000
# reached  0.7
# reached  0.38 switch to crying
# location 6894
# on  7000
# reached  0.45
# epsilon back on to  0.05
# one epsilon changed to: 0.025
# reached  2.91
# on  8000
# reached  4.61
# on  9000
# reached  3.6
# fold reached  6.2
# on  10000
# reached  3.11
# fold reached  4.49
# two epsilon changed to: 0.0125
# reached  1.99
# on  11000
# reached  1.84
# on  12000
# reached  1.65
# tre epsilon changed to: 0.00625
# reached  0.99
# on  13000
# reached  1.49
# fold reached  1.75
# on  14000
# reached  1.03
# on  15000
# reached  0.77
# fold reached  1.24
# on  16000
# reached  0.87
# fold reached  1.17
# on  17000
# reached  0.59
# fold reached  0.78
# number of purple and blue episodes:  5364
# red  has count  6214
# green  has count  6229
# blue  has count  2744
# purple  has count  2620
# size of dictionary  1632
# last 100 runs average:  0.46
# Model: "sequential_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_19 (Dense)             (None, 1)                 2048
# =================================================================
# Total params: 2,048
# Trainable params: 2,048
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_20"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_20 (Dense)             (None, 1)                 2048
# =================================================================
# Total params: 2,048
# Trainable params: 2,048
# Non-trainable params: 0
# _________________________________________________________________
# on  1000
# reached  8.49
# on  2000
# reached  6.32
# on  3000
# reached  4.42
# on  4000
# reached  3.43
# one epsilon changed to: 0.025
# reached  2.98
# two epsilon changed to: 0.0125
# reached  1.91
# on  5000
# reached  2.45
# on  6000
# reached  1.99
# tre epsilon changed to: 0.00625
# reached  0.99
# on  7000
# reached  1.17
# reached  0.48 switch to crying
# location 7403
# epsilon back on to  0.05
# on  8000
# reached  5.51
# fold reached  9.12
# on  9000
# reached  4.99
# one epsilon changed to: 0.025
# reached  2.98
# two epsilon changed to: 0.0125
# reached  1.92
# on  10000
# reached  1.77
# on  11000
# reached  2.88
# fold reached  4.06
# on  12000
# reached  1.86
# fold reached  2.78
# on  13000
# reached  1.46
# fold reached  2.09
# tre epsilon changed to: 0.00625
# reached  0.99
# on  14000
# reached  1.76
# on  15000
# reached  1.04
# fold reached  1.34
# on  16000
# reached  1.01
# fold reached  1.61
# on  17000
# reached  0.84
# number of purple and blue episodes:  5130
# red  has count  6239
# green  has count  6338
# purple  has count  2539
# blue  has count  2591
# size of dictionary  1632
# last 100 runs average:  0.42

# %%
len_memory_store
# Out:
# [1632, 1632, 1632, 1632, 1632, 1632, 1632, 1632, 1632, 1632]

# %%
fold_counter_ar
# Out:
# [4658, 4817, 5041, 4858, 4855, 4856, 5170, 5916, 5364, 5130]

# %%
stan_error = np.std(fold_counter_ar)/np.sqrt(len(fold_counter_ar))

# %%
mean = np.mean(fold_counter_ar)
mean
# Out:
# 5066.5

# %%
upper_limit = mean + (1.96 * stan_error)
upper_limit
# Out:
# 5280.058032899725

# %%
lower_limit = mean - (1.96 * stan_error)
lower_limit
# Out:
# 4852.941967100275

# %%
1.96 * stan_error
# Out:
# 213.55803289972494
